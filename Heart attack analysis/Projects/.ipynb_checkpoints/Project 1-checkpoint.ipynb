# %% [markdown]
# # Heart Attack Exploratory and Predictive Data Analysis
#
#
#
# ### Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
heart = pd.read_csv('../heart.csv')
oxy = pd.read_csv('../o2Saturation.csv')

# %%
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# After checking the columns and the data, we can identify some columns to be categorical and some to be numerical.

# %% [markdown]
# ### Columns in the dataset
#
# Age : Age of the patient Sex : Sex of the patient
#
# Exang : exercise induced angina (1 = yes; 0 = no)
#
# Ca : number of major vessels (0-3)
#
# Cp : Chest Pain type chest pain type
#     Value 1: typical angina
#     Value 2: atypical angina
#     Value 3: non-anginal pain
#     Value 4: asymptomatic
#
# trtbps : resting blood pressure (in mm Hg)
#
# Chol : cholestoral in mg/dl fetched via BMI sensor
#
# Fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
# Rest_ecg : resting electrocardiographic results
#     Value 0: normal
#     Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#     Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
# Thalach : maximum heart rate achieved
#
# Target : 0= less chance of heart attack 1= more chance of heart attack

# %%
heart.isna().sum()
# to find out any missing values in the dataset
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
heart.duplicated().sum()
#found out the duplicated values in the dataset.
# Out:
# 1

# %%
heart.drop_duplicates(inplace=True)
heart.duplicated().sum()
#dropped out the duplicated values and checked the dataset again for duplicates.
# Out:
# 0

# %%
heart.describe()
# Out:
#              age         sex          cp      trtbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
heart.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trtbps    0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalachh -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exng      0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slp      -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# caa       0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thall     0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
sns.countplot(x='output', data=heart, palette='rocket')
# Out:
# <AxesSubplot:xlabel='output', ylabel='count'>

# %% [markdown]
# ### Differentiating into categorical and numerical features.

# %%
cat_features = ['sex', 'cp', 'fbs', 'restecg', 'exng', 'caa', 'thall', 'slp', 'output']

# %%
num_features = [item for item in heart.columns if item != 'index' and item not in cat_features]

# %% [markdown]
# ### Visualizations for categorical features

# %%
for feature in cat_features:
    cat = heart[feature].value_counts()
    sns.barplot(cat.index, cat, palette='rocket')
    
    plt.title(feature + " distribution")
    plt.show()

# %% [markdown]
# ### Visualizations for numerical features

# %%
for feature in num_features:
    heart[feature].hist()
    plt.title(feature + " distribution")
    plt.show()

# %%
plt.figure(figsize=(18,8))
sns.heatmap(heart.corr(), annot=True)
# Out:
# <AxesSubplot:>
